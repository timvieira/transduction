# %%
# %load_ext autoreload
# %autoreload 2

# %%
from transduction.lazy import Lazy, LazyDeterminize
from transduction.fsa import FSA, EPSILON
from transduction import (
    FST, EPSILON, PrecoverDecomp, examples, Precover,
    LazyRecursive, BuggyLazyRecursive, EagerNonrecursive, LazyPrecoverNFA, LazyNonrecursive,    
)
from transduction.util import display_table

# %%
#fst = examples.replace([('1', 'a'), ('2', 'b'), ('3', 'c'), ('4', 'd'), ('5', 'e')])
fst = examples.samuel_example()
target = 'c'
fst.graphviz(fmt_node=lambda x: x)

# %%
precover = Precover(fst, target)
precover

# %%
from collections import deque
def materialize(self, max_steps):
    "Materialized this automaton using a depth-first traversal from its initial states."
    m = FSA()
    worklist = deque()
    visited = set()
    for i in self.start():
        worklist.append(i)
        m.add_start(i)
        if self.is_final(i):
            m.add_stop(i)    
    t = 0
    while worklist:
        i = worklist.popleft()
        t += 1
        if t > max_steps: break
        if i in visited: continue
        visited.add(i)
        for a, j in self.arcs(i):
            worklist.append(j)
            m.add(i,a,j)
            if self.is_final(j):
                m.add_stop(j)
    return m

# %% [markdown]
# Target-side buffering pushes the target string into the state of the (infinite-state) machine.

# %%
class TargetSideBuffer(Lazy):

    def __init__(self, f):
        self.f = f

    def arcs(self, state):
        (i, ys) = state
        for x,y,j in self.f.arcs(i):
            yield x, (j, ys + y)

    def start(self):
        for i in self.f.I:
            yield (i, '')

    def is_final(self, state):
        return True

# %%
materialize(TargetSideBuffer(fst), 50).det()   # truncated because it is infinite state
# Out:
# {
#   {(4, 'yxxxxxxxxx')}$:
#     b -> {(4, 'yxxxxxxxxxx')}
#     a -> {(4, 'yxxxxxxxxxx')}
#   {(4, 'yxxxxxxxxxxx')}$:
#     b -> {(4, 'yxxxxxxxxxxxx')}
#     a -> {(4, 'yxxxxxxxxxxxx')}
#   {(4, 'cxxx')}$:
#     b -> {(4, 'cxxxx')}
#     a -> {(4, 'cxxxx')}
#   {(4, 'cxxxxxxxxxxxx')}$:
#     b -> {(4, 'cxxxxxxxxxxxxx')}
#     a -> {(4, 'cxxxxxxxxxxxxx')}
#   {(4, 'yxxxxxxxxxxxx')}$:
#     b -> {}
#     a -> {}
#   {(4, 'yxxxxxxxx')}$:
#     b -> {(4, 'yxxxxxxxxx')}
#     a -> {(4, 'yxxxxxxxxx')}
#   {(4, 'cxxxxxxxxxxx')}$:
#     b -> {(4, 'cxxxxxxxxxxxx')}
#     a -> {(4, 'cxxxxxxxxxxxx')}
#   {(4, 'cxx')}$:
#     b -> {(4, 'cxxx')}
#     a -> {(4, 'cxxx')}
#   {(4, 'yxxx')}$:
#     b -> {(4, 'yxxxx')}
#     a -> {(4, 'yxxxx')}
#   {(4, 'cxxxx')}$:
#     b -> {(4, 'cxxxxx')}
#     a -> {(4, 'cxxxxx')}
#   {(4, 'cxxxxxxx')}$:
#     b -> {(4, 'cxxxxxxxx')}
#     a -> {(4, 'cxxxxxxxx')}
#   {(4, 'cxxxxx')}$:
#     b -> {(4, 'cxxxxxx')}
#     a -> {(4, 'cxxxxxx')}
# ...

# %% [markdown]
# This machine has a lot of irrelevant states for our specific target string, so we can prune its arcs.

# %%
class Relevance(Lazy):

    def __init__(self, base, target):
        self.base = base
        self.target = target

    def arcs(self, state):
        N = len(self.target)
        for x, (i, ys) in self.base.arcs(state):
            if self.target.startswith(ys) or ys.startswith(self.target):
                yield x, (i, ys)

    def start(self):
        yield from self.base.start()

    def is_final(self, state):
        (i, ys) = state
        return self.base.is_final(state) and ys.startswith(self.target)

# %%
materialize(Relevance(TargetSideBuffer(fst), target), 20)
# Out:
# {
#   (4, 'cxxxxxxx')$:
#     a -> (4, 'cxxxxxxxx')
#     b -> (4, 'cxxxxxxxx')
#   (3, 'c')$:
#      -> (4, 'cx')
#   (4, 'cxxxxxxxx')$:
#     a -> (4, 'cxxxxxxxxx')
#     b -> (4, 'cxxxxxxxxx')
#   ^(0, ''):
#     a -> (1, '')
#     a -> (2, 'c')
#   (4, 'cxxxxxx')$:
#     a -> (4, 'cxxxxxxx')
#     b -> (4, 'cxxxxxxx')
#   (4, 'cx')$:
#     a -> (4, 'cxx')
#     b -> (4, 'cxx')
#   (4, 'cxxx')$:
#     a -> (4, 'cxxxx')
#     b -> (4, 'cxxxx')
#   (4, 'cxxxxxxxxx')$:
#   (4, 'cxxxxx')$:
#     a -> (4, 'cxxxxxx')
#     b -> (4, 'cxxxxxx')
#   (4, 'cxxxx')$:
#     a -> (4, 'cxxxxx')
#     b -> (4, 'cxxxxx')
#   (1, ''):
#     b -> (3, 'c')
#   (4, 'cxx')$:
#     a -> (4, 'cxxx')
#     b -> (4, 'cxxx')
#   (2, 'c')$:
#     a -> (4, 'cx')
# }

# %%
materialize(LazyDeterminize(Relevance(TargetSideBuffer(fst), target)), 20)
# Out:
# {
#   {(4, 'cxxx')}$:
#     a -> {(4, 'cxxxx')}
#     b -> {(4, 'cxxxx')}
#   {(4, 'cxxxxxx')}$:
#     a -> {(4, 'cxxxxxxx')}
#     b -> {(4, 'cxxxxxxx')}
#   {(1, ''),(2, 'c')}$:
#     b -> {(3, 'c'),(4, 'cx')}
#     a -> {(4, 'cx')}
#   {(4, 'cxxxx')}$:
#     a -> {(4, 'cxxxxx')}
#     b -> {(4, 'cxxxxx')}
#   {(4, 'cxxxxxxx')}$:
#     a -> {(4, 'cxxxxxxxx')}
#     b -> {(4, 'cxxxxxxxx')}
#   {(4, 'cxxxxxxxxx')}$:
#   {(4, 'cxxxxxxxx')}$:
#     a -> {(4, 'cxxxxxxxxx')}
#     b -> {(4, 'cxxxxxxxxx')}
#   ^{(0, '')}:
#     a -> {(1, ''),(2, 'c')}
#   {(4, 'cxx')}$:
#     a -> {(4, 'cxxx')}
#     b -> {(4, 'cxxx')}
#   {(4, 'cxxxxx')}$:
#     a -> {(4, 'cxxxxxx')}
#     b -> {(4, 'cxxxxxx')}
#   {(4, 'cx')}$:
#     a -> {(4, 'cxx')}
#     b -> {(4, 'cxx')}
#   {(3, 'c'),(4, 'cx')}$:
#     a -> {(4, 'cxx')}
#     b -> {(4, 'cxx')}
# }

# %% [markdown]
# The state machine above is infinite, but if we stare at its states, we realize that there is no need to keep tracking the target-side string after we have emitted the target string.  And, that is sufficient for us to tie the knot.  **Unfortunately, we lose the state information needed for tracking extensions of the target string.**

# %%
class Truncate(Lazy):

    def __init__(self, base, target):
        self.base = base
        self.target = target

    def arcs(self, state):
        N = len(self.target)
        for x, (i, ys) in self.base.arcs(state):
            yield x, (i, ys[:N])

    def start(self):
        yield from self.base.start()

    def is_final(self, state):
        (i, ys) = state
        return self.base.is_final(state) and ys.startswith(self.target)

# %%
materialize(Truncate(Relevance(TargetSideBuffer(fst), target), target), 20)
# Out:
# {
#   (4, 'c')$:
#     a -> (4, 'c')
#     b -> (4, 'c')
#   ^(0, ''):
#     a -> (1, '')
#     a -> (2, 'c')
#   (2, 'c')$:
#     a -> (4, 'c')
#   (3, 'c')$:
#      -> (4, 'c')
#   (1, ''):
#     b -> (3, 'c')
# }

# %%
materialize(LazyDeterminize(Truncate(Relevance(TargetSideBuffer(fst), target), target)), 20)
# Out:
# {
#   ^{(0, '')}:
#     a -> {(1, ''),(2, 'c')}
#   {(1, ''),(2, 'c')}$:
#     b -> {(4, 'c'),(3, 'c')}
#     a -> {(4, 'c')}
#   {(4, 'c'),(3, 'c')}$:
#     a -> {(4, 'c')}
#     b -> {(4, 'c')}
#   {(4, 'c')}$:
#     a -> {(4, 'c')}
#     b -> {(4, 'c')}
# }

# %% [markdown]
# Determinization still works

# %%
#D = materialize(LazyDeterminize(Truncate(Relevance(TargetSideBuffer(fst), target), target)), 20)
DD = LazyDeterminize(Relevance(TargetSideBuffer(fst), target))
D = materialize(DD, 12)
D
# Out:
# {
#   {(4, 'cxxx')}$:
#     a -> {(4, 'cxxxx')}
#     b -> {(4, 'cxxxx')}
#   {(1, ''),(2, 'c')}$:
#     b -> {(3, 'c'),(4, 'cx')}
#     a -> {(4, 'cx')}
#   {(4, 'cxxxx')}$:
#     a -> {(4, 'cxxxxx')}
#     b -> {(4, 'cxxxxx')}
#   ^{(0, '')}:
#     a -> {(1, ''),(2, 'c')}
#   {(4, 'cxx')}$:
#     a -> {(4, 'cxxx')}
#     b -> {(4, 'cxxx')}
#   {(4, 'cxxxxx')}$:
#   {(4, 'cx')}$:
#     a -> {(4, 'cxx')}
#     b -> {(4, 'cxx')}
#   {(3, 'c'),(4, 'cx')}$:
#     a -> {(4, 'cxx')}
#     b -> {(4, 'cxx')}
# }

# %%
def continuity(self, frontier, target, alphabet):

    def refine(frontier):
        # Clip the target string state variable to `target`, as this mimics the states of 
        # the composition machine for the complete string `target`, we haven't limited it 
        # to this point, which means that we have an infinite-state machine.
        N = len(target)
        return frozenset({
            (i, ys[:N]) for i, ys in frontier
            if ys[:N].startswith(target)
        })

    def arcs(i):
        for x, j in self.arcs(i):
            yield x, j

    def is_final(xs):
        return any(ys.startswith(target) for i, ys in frontier if fst.is_final(i))

    worklist = []
    worklist.append(frontier)
    visited = {refine(frontier)}
    while worklist:
        i = worklist.pop()
        if not is_final(i): return False
        dest = dict(arcs(i))
        for a in alphabet:
            if a not in dest: return False
            j = dest[a]
            jj = refine(j)
            if jj not in visited:
                visited.add(jj)
                worklist.append(j)
    return True

# %%
for i in sorted(D.states, key=lambda i: max(ys for _, ys in i)):
    print(i)
    states = {j for j, _ in i}
    print((colors.light.green % 'UNIVERSAL') if continuity(DD, i, target, fst.A - {EPSILON}) else 'not universal')
    display_table([[fst.graphviz(sty_node=lambda x: {
        'style': 'filled,rounded',
        'fillcolor': '#F9E6E6' if x in states else '#ffffff',
    }), D.graphviz(sty_node=lambda x: {
        'style': 'filled,rounded',
        'fillcolor': '#F9E6E6' if x == i else '#ffffff',
    })]])
# Out:
# {(0, '')}
# not universal
# <table class="fmt-table" style="border-collapse:collapse;"><tbody><tr><td style="vertical-align:top"><?xml version="1.0" encoding="UTF-8" standalone="no"?>
# <!DOCTYPE svg PUBLIC "-//W3C//DTD SVG 1.1//EN"
#  "http://www.w3.org/Graphics/SVG/1.1/DTD/svg11.dtd">
# <!-- Generated by graphviz version 2.43.0 (0)
#  -->
# <!-- Title: %3 Pages: 1 -->
# <svg width="278pt" height="90pt"
#  viewBox="0.00 0.00 278.00 90.10" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
# <g id="graph0" class="graph" transform="scale(1 1) rotate(0) translate(4 86.1)">
# <title>%3</title>
# <polygon fill="white" stroke="transparent" points="-4,4 -4,-86.1 274,-86.1 274,4 -4,4"/>
# <!-- start_0 -->
# <g id="node1" class="node">
# <title>start_0</title>
# <ellipse fill="black" stroke="black" cx="0" cy="-31.6" rx="0" ry="0"/>
# </g>
# <!-- 0 -->
# <g id="node2" class="node">
# <title>0</title>
# ...

# %%
class Quotient(Lazy):

    def __init__(self, base, is_universal):
        self.base = base
        self.is_universal = is_universal

    def arcs(self, state):
        if self.is_universal(state): return
        yield from self.base.arcs(state)

    def start(self):
        yield from self.base.start()

    def is_final(self, state):
        return self.base.is_final(state) and self.is_universal(state)

# %%
class Remainder(Lazy):

    def __init__(self, base, is_universal):
        self.base = base
        self.is_universal = is_universal

    def arcs(self, state):
        if self.is_universal(state): return
        yield from self.base.arcs(state)

    def start(self):
        yield from self.base.start()

    def is_final(self, state):
        return self.base.is_final(state) and not self.is_universal(state)

# %%
# This universality test is incorrect; I'm having a little trouble with the puzzle of keeping the spill over in the state, 
# but still limiting the infinitude of the state machine. 
def my_universal_test(state):    
    for i, ys in state:
        if ys.startswith(target):
            return True
    return False

# %%
materialize(Quotient(LazyDeterminize(Relevance(TargetSideBuffer(fst), target)), my_universal_test), 20).graphviz(fmt_node=set)

# %%
materialize(Remainder(LazyDeterminize(Relevance(TargetSideBuffer(fst), target)), my_universal_test), 20).graphviz(fmt_node=set)
