# %%
from transduction.rust_bridge import RustDecomp
from transduction.examples import triplets_of_doom

# %%
m = RustDecomp(triplets_of_doom(), 'a')

# %%
m.quotient.min()
# Out:
# {
# }

# %%
m.remainder.min()
# Out:
# {
#   0$:
#     a -> 4
#     b -> 1
#   1:
#     b -> 3
#   2:
#     a -> 0
#   3:
#     b -> 0
#   4:
#     a -> 2
#   ^5:
#     a -> 4
# }
