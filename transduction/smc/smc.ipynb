# %%
from transduction.smc.smc import SMC
from transduction.smc.lm.aa import create_dna_translator
from transduction.smc.lm.lm import HFLM
from transduction.lazy_recursive import LazyRecursive

# %% [markdown]
# # Benchmarking

# %%
scorer = HFLM()
fst = create_dna_translator()
# Out:
# Loading model vesteinn/gpt2-dna on cuda...

# %%
long_seq = "..."
print(len(long_seq))
N=10
smc = SMC(fst, LazyRecursive, long_seq[:256], scorer, num_particles=N)
#smc.get_probs()
# Out:
# 731

# %%
from transduction.smc.lm.evo_lm import Evo2Scorer

escorer = Evo2Scorer()
N=10
smc = SMC(fst, LazyRecursive, long_seq, escorer, num_particles=N)


smc.get_probs()
# Out:
# ...
# Loading model evo2_1b_base on cuda...
# Fetching 4 files:   0%|          | 0/4 [00:00<?, ?it/s]
# Found complete file in repo: evo2_1b_base.pt
# [12/08/25 12:26:02] INFO     StripedHyena - INFO - Initializing StripedHyena with config:              ]8;id=747601;file:///home/vesteinn/miniconda3/envs/tlm/lib/python3.12/site-packages/vortex/model/model.py\model.py]8;;\:]8;id=784325;file:///home/vesteinn/miniconda3/envs/tlm/lib/python3.12/site-packages/vortex/model/model.py#616\616]8;;\
#                              {'model_name': 'shc-evo2-1b-8k-2T-v2', 'vocab_size': 512, 'hidden_size':
#                              1920, 'num_filters': 1920, 'attn_layer_idxs': [3, 10, 17, 24],
#                              'hcl_layer_idxs': [2, 6, 9, 13, 16, 20, 23], 'hcm_layer_idxs': [1, 5, 8,
#                              12, 15, 19, 22], 'hcs_layer_idxs': [0, 4, 7, 11, 14, 18, 21],
#                              'hcm_filter_length': 128, 'hcl_filter_groups': 1920, 'hcm_filter_groups':
# ...
